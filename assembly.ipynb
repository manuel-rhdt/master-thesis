# %%
from analyzer import analyzer
import numpy as np

# %%
analyzer.time_average(np.array([1.0, 2.0]), np.array([0.0, 1.0]), np.array([0.5, 1.5]))
# Out:
# array([1.5])

# %%
print(list(analyzer.time_average.inspect_asm().values())[0])
# Out:
# 	.section	__TEXT,__text,regular,pure_instructions
# 	.macosx_version_min 10, 15
# 	.section	__TEXT,__literal8,8byte_literals
# 	.p2align	3
# LCPI0_0:
# 	.quad	9218868437227405312
# 	.section	__TEXT,__text,regular,pure_instructions
# 	.globl	__ZN8analyzer8analyzer16time_average$241E5ArrayIdLi1E1C7mutable7alignedE5ArrayIdLi1E1C7mutable7alignedE5ArrayIdLi1E1C7mutable7alignedE27omitted$28default$3dNone$2927omitted$28default$3dNone$29
# 	.p2align	4, 0x90
# __ZN8analyzer8analyzer16time_average$241E5ArrayIdLi1E1C7mutable7alignedE5ArrayIdLi1E1C7mutable7alignedE5ArrayIdLi1E1C7mutable7alignedE27omitted$28default$3dNone$2927omitted$28default$3dNone$29:
# 	.cfi_startproc
# 	pushq	%rbp
# 	.cfi_def_cfa_offset 16
# 	pushq	%r15
# 	.cfi_def_cfa_offset 24
# 	pushq	%r14
# 	.cfi_def_cfa_offset 32
# 	pushq	%r13
# 	.cfi_def_cfa_offset 40
# 	pushq	%r12
# 	.cfi_def_cfa_offset 48
# 	pushq	%rbx
# 	.cfi_def_cfa_offset 56
# 	subq	$56, %rsp
# 	.cfi_def_cfa_offset 112
# 	.cfi_offset %rbx, -56
# ...
